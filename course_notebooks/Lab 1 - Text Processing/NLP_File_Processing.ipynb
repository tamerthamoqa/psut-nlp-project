# %%
import requests
import json
import pandas

# %% [markdown]
# ### Processing Text **Files**

# %%
#Create an empty text file
open('data.txt','x')
# Out:
# <_io.TextIOWrapper name='data.txt' mode='x' encoding='UTF-8'>

# %%
#Write to a file
myfile=open('data.txt','w')
myfile.write(' This is my first textfile.\n I want to say something nice.\n But Im not in good mode.\n')
myfile.close()

# %%
#Read a text File
myfile=open('data.txt','r')
myfile.read()
# Out:
# 'This is my first textfile.\n I want to say something nice.\n But Im not in good mode.\n'

# %%
#Read a text File
myfile=open('data.txt','r')
print('Statement 1=> '+ myfile.readline())
print('Statement 2=> '+ myfile.readline())
print('Statement 3=> '+ myfile.readline())
# Out:
# Statement 1=> This is my first textfile.
#
# Statement 2=>  I want to say something nice.
#
# Statement 3=>  But Im not in good mode.

# %%
#Append to a file
myfile=open('data.txt','a')
myfile.write(' This is not the end.\n I have to be clever.\n')
myfile.close()

# %%
#Read a text File
myfile=open('data.txt','r')
for line in myfile:
  print(line)
# Out:
# This is my first textfile.
#
#  I want to say something nice.
#
#  But Im not in good mode.
#
# This is not the end.
#
#  I have to be clever.
#
#  This is not the end.
#
#  I have to be clever.

# %%
#Delete a File
#import os
#if os.path.exists("demofile.txt"):
#  os.remove("demofile.txt")
#else:
#  print("The file does not exist")

# %% [markdown]
# ### **PDF Files**

# %%
# !pip install  PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading PyPDF2-1.26.0.tar.gz (77 kB)
#      |████████████████████████████████| 77 kB 2.7 MB/s
# Building wheels for collected packages: PyPDF2
#   Building wheel for PyPDF2 (setup.py) ... done
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61102 sha256=b6d77bb0f12f37239e98d920198cec63dcceb218ae80175a11494abe9d6da230
#   Stored in directory: /root/.cache/pip/wheels/80/1a/24/648467ade3a77ed20f35cfd2badd32134e96dd25ca811e64b3
# Successfully built PyPDF2
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-1.26.0

# %%
import PyPDF2

# %%
f = open('US_Declaration.pdf','rb')
pdf_reader = PyPDF2.PdfFileReader(f)
pdf_reader.numPages
pdf_reader.pages
page_one = pdf_reader.getPage(0)
page_one_text = page_one.extractText()
print(page_one_text)
print(pdf_reader.getPage(0).extractText().split())

# %%
f = open('US_Declaration.pdf','rb')

# List of every page's text.
# The index will correspond to the page number.
pdf_text = [0]  # zero is a placehoder to make page 1 = index 1

pdf_reader = PyPDF2.PdfFileReader(f)

for p in range(pdf_reader.numPages):
    
    page = pdf_reader.getPage(p)
    
    pdf_text.append(page.extractText())

f.close()

print(pdf_text)

# %%
f = open('US_Declaration.pdf','rb')
pdf_reader = PyPDF2.PdfFileReader(f)

first_page = pdf_reader.getPage(0)
first_page.extractText()

# %%
pdf_writer = PyPDF2.PdfFileWriter()
pdf_writer.addPage(first_page)
pdf_output = open("new file.pdf","wb")
pdf_writer.write(pdf_output)
pdf_output.close()

# %%
from PyPDF2 import PdfFileMerger, PdfFileReader,  PdfFileWriter

filename1 = 'F1.pdf'
filename2 = 'F2.pdf'

merger = PdfFileMerger()

merger.append(PdfFileReader(open(filename1, 'rb')))
merger.append(PdfFileReader(open(filename2, 'rb')))

merger.write("merged file 1.pdf")

# %% [markdown]
# ### **From Internet**

# %%
import re
prog=re.compile(r'<.*?>')

r=requests.get('https://www.psut.edu.jo')
#print(r.text)
print(prog.sub('',r.text))

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(r.text,'html5lib')
print(soup.get_text())
# Out:
#
#
#
#
#
#   Home | PSUT
#
# @import url("https://psut.edu.jo/modules/system/system.base.css?r7e2vv");
#
#
# @import url("https://psut.edu.jo/sites/all/modules/contrib/simplenews/simplenews.css?r7e2vv");
# @import url("https://psut.edu.jo/profiles/twix/modules/date/date_api/date.css?r7e2vv");
# @import url("https://psut.edu.jo/profiles/twix/modules/date/date_popup/themes/datepicker.1.7.css?r7e2vv");
# @import url("https://psut.edu.jo/modules/field/theme/field.css?r7e2vv");
# @import url("https://psut.edu.jo/profiles/twix/modules/views/css/views.css?r7e2vv");
# @import url("https://psut.edu.jo/profiles/twix/modules/ckeditor/css/ckeditor.css?r7e2vv");
#
#
# @import url("https://psut.edu.jo/profiles/twix/modules/colorbox/styles/stockholmsyndrome/colorbox_style.css?r7e2vv");
# @import url("https://psut.edu.jo/profiles/twix/modules/ctools/css/ctools.css?r7e2vv");
# @import url("https://psut.edu.jo/sites/all/modules/contrib/dhtml_menu/dhtml_menu.css?r7e2vv");
# @import url("https://psut.edu.jo/sites/all/modules/contrib/ie6nomore/ie6nomore.css?r7e2vv");
# @import url("https://psut.edu.jo/sites/all/modules/contrib/lightbox2/css/lightbox.css?r7e2vv");
# @import url("https://psut.edu.jo/profiles/twix/modules/panels/css/panels.css?r7e2vv");
# @import url("https://psut.edu.jo/profiles/twix/modules/panels/plugins/layouts/flexible/flexible.css?r7e2vv");
# @import url("https://psut.edu.jo/sites/default/files/ctools/css/3c29689d86d7c486d731add073be05a1.css?r7e2vv");
# @import url("https://psut.edu.jo/modules/locale/locale.css?r7e2vv");
# @import url("https://psut.edu.jo/sites/all/modules/contrib/responsive_menus/styles/responsive_menus_simple/css/responsive_menus_simple.css?r7e2vv");
# @import url("https://psut.edu.jo/sites/all/modules/contrib/addtoany/addtoany.css?r7e2vv");
# @import url("https://psut.edu.jo/sites/all/libraries/superfish/css/superfish.css?r7e2vv");
#
#
#
# @import url("https://psut.edu.jo/sites/all/themes/bootstrap/css/overrides.css?r7e2vv");
# @import url("https://psut.edu.jo/sites/all/themes/dotstrap/stylesheets/styles.css?r7e2vv");
# @import url("https://psut.edu.jo/sites/all/themes/dotstrap/font-awesome/css/font-awesome.min.css?r7e2vv");
#
#
# @import url("https://psut.edu.jo/sites/all/themes/dotstrap/stylesheets/laptop.css?r7e2vv");
#
#
# @import url("https://psut.edu.jo/sites/all/themes/dotstrap/stylesheets/mobile-tablet.css?r7e2vv");
#
#
# @import url("https://psut.edu.jo/sites/all/themes/dotstrap/stylesheets/responsive-custom.css?r7e2vv");
#
#
# @import url("https://psut.edu.jo/sites/all/themes/dotstrap/stylesheets/print.css?r7e2vv");
#
#
# @import url("https://psut.edu.jo/sites/all/themes/dotstrap/flexslider/flexslider.css?r7e2vv");
#
#
#
#
# window.jQuery || document.write("<script src='/profiles/twix/modules/jquery_update/replace/jquery/1.7/jquery.min.js'>\x3C/script>")
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# (function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","https://www.google-analytics.com/analytics.js","ga");ga("create", "UA-48357427-11", {"cookieDomain":"auto"});ga("set", "anonymizeIp", true);ga("send", "pageview");
#
#
#
#
#
#
#
#
#
#
#
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"dotstrap","theme_token":"GH54zR5eaRgD6btE2EnEzzFLB7rRV0LC5pJ2eSe9fmw","jquery_version":"1.7","js":{"sites\/all\/modules\/contrib\/browserclass\/js\/browserclass.js":1,"sites\/all\/themes\/bootstrap\/js\/bootstrap.js":1,"\/\/code.jquery.com\/jquery-1.7.2.min.js":1,"0":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"profiles\/twix\/modules\/jquery_update\/replace\/ui\/external\/jquery.cookie.js":1,"profiles\/twix\/modules\/jquery_update\/replace\/misc\/jquery.form.min.js":1,"misc\/ajax.js":1,"profiles\/twix\/modules\/jquery_update\/js\/jquery_update.js":1,"\/\/netdna.bootstrapcdn.com\/bootstrap\/3.0.2\/js\/bootstrap.min.js":1,"sites\/all\/modules\/custom\/darksite\/script.js":1,"sites\/all\/libraries\/colorbox\/jquery.colorbox-min.js":1,"profiles\/twix\/modules\/colorbox\/js\/colorbox.js":1,"profiles\/twix\/modules\/colorbox\/styles\/stockholmsyndrome\/colorbox_style.js":1,"sites\/all\/modules\/contrib\/dhtml_menu\/dhtml_menu.js":1,"sites\/all\/modules\/contrib\/ie6nomore\/ie6nomore.js":1,"sites\/all\/modules\/contrib\/lightbox2\/js\/lightbox.js":1,"profiles\/twix\/modules\/views\/js\/base.js":1,"sites\/all\/themes\/bootstrap\/js\/misc\/_progress.js":1,"profiles\/twix\/modules\/views\/js\/ajax_view.js":1,"sites\/all\/modules\/contrib\/responsive_menus\/styles\/responsive_menus_simple\/js\/responsive_menus_simple.js":1,"sites\/all\/modules\/google_analytics\/googleanalytics.js":1,"1":1,"sites\/all\/libraries\/superfish\/jquery.hoverIntent.minified.js":1,"sites\/all\/libraries\/superfish\/sfsmallscreen.js":1,"sites\/all\/libraries\/superfish\/supposition.js":1,"sites\/all\/libraries\/superfish\/superfish.js":1,"sites\/all\/libraries\/superfish\/supersubs.js":1,"sites\/all\/modules\/contrib\/superfish\/superfish.js":1,"sites\/all\/themes\/dotstrap\/js\/script.js":1,"https:\/\/psut.cscbeyond.com\/chatbot\/combined.js?v=4":1,"sites\/all\/themes\/dotstrap\/flexslider\/jquery.flexslider-min.js":1,"sites\/all\/themes\/bootstrap\/js\/modules\/views\/js\/ajax_view.js":1,"sites\/all\/themes\/bootstrap\/js\/misc\/ajax.js":1},"css":{"modules\/system\/system.base.css":1,"sites\/all\/modules\/contrib\/simplenews\/simplenews.css":1,"profiles\/twix\/modules\/date\/date_api\/date.css":1,"profiles\/twix\/modules\/date\/date_popup\/themes\/datepicker.1.7.css":1,"modules\/field\/theme\/field.css":1,"profiles\/twix\/modules\/views\/css\/views.css":1,"profiles\/twix\/modules\/ckeditor\/css\/ckeditor.css":1,"profiles\/twix\/modules\/colorbox\/styles\/stockholmsyndrome\/colorbox_style.css":1,"profiles\/twix\/modules\/ctools\/css\/ctools.css":1,"sites\/all\/modules\/contrib\/dhtml_menu\/dhtml_menu.css":1,"sites\/all\/modules\/contrib\/ie6nomore\/ie6nomore.css":1,"sites\/all\/modules\/contrib\/lightbox2\/css\/lightbox.css":1,"profiles\/twix\/modules\/panels\/css\/panels.css":1,"profiles\/twix\/modules\/panels\/plugins\/layouts\/flexible\/flexible.css":1,"public:\/\/ctools\/css\/3c29689d86d7c486d731add073be05a1.css":1,"modules\/locale\/locale.css":1,"sites\/all\/modules\/contrib\/responsive_menus\/styles\/responsive_menus_simple\/css\/responsive_menus_simple.css":1,"sites\/all\/modules\/contrib\/addtoany\/addtoany.css":1,"sites\/all\/libraries\/superfish\/css\/superfish.css":1,"\/\/netdna.bootstrapcdn.com\/bootstrap\/3.0.2\/css\/bootstrap.min.css":1,"sites\/all\/themes\/bootstrap\/css\/overrides.css":1,"sites\/all\/themes\/dotstrap\/stylesheets\/styles.css":1,"sites\/all\/themes\/dotstrap\/font-awesome\/css\/font-awesome.min.css":1,"sites\/all\/themes\/dotstrap\/stylesheets\/laptop.css":1,"sites\/all\/themes\/dotstrap\/stylesheets\/mobile-tablet.css":1,"sites\/all\/themes\/dotstrap\/stylesheets\/responsive-custom.css":1,"sites\/all\/themes\/dotstrap\/stylesheets\/print.css":1,"sites\/all\/themes\/dotstrap\/flexslider\/flexslider.css":1}},"colorbox":{"transition":"elastic","speed":"350", ...
#
#
#
#
#
#
#
#
#     Skip to main content
#
#
#
#
#
#
#
#
#
#
#
#
#
#   facebook
# Twitter
# Youtube
#
#
#
#
#
#   عربي
#
#
#
#
#
#   Site map
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       Search form
#     Search
#
#
#
#
#
#
#
#
#   HomeEl Hassan  AwardUniversityPresidencyAboutInternational Relations OfficeQueen Rania Center for EntrepreneurshipPSUT Sustainability PoliciesPublic Relations and PressResearch & DevelopmentDiwanVisitorsLinksPartnersAnnual Report & ProspectusSuccess StoriesAcademicsKing Hussein School of Computing SciencesKing Abdullah II School of EngineeringKing Talal School of Business TechnologyKing Abdullah I School of Graduate Studies and Scientific ResearchTeach YourselfDeanshipsDeanship of Admissions and RegistrationDeanship of Student AffairsUnitsEl Hassan LibraryCenter of Consultancy and TrainingCenter of Excellence for Library Services at Jordanian Private UniversitiesE-Learning CenterAdministrative AffairsFinancial AffairsInternal Audit OfficeQuality Assurance and Accreditation CenterHealth CenterMorejobsContact UsANNOUNCEMENTSLibrary and DownloadsNewsPhoto GalleryVideo Gallery
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ضرورة التزام جميع الزوار والمراجعين بأوامر الدفاع
#
#
# Read More
#
#
#
#
#
#
# QS Stars
# Online Learning
# النجوم الخمس في التقييم العالمي
#  QS Stars
# في
#
# حقل التعليم والتعلّم الإلكتروني
#
#
#
# وذلك لدور الجامعة البارز بتطوير التعليم الإلكتروني وديمومته، وعلى الخدمات والتكنولوجيا المقدَّمة من قبل الجامعة، وتصدير الخدمات وتبادل الخبرات، وانخراط الطلبة مع أساتذتهم في محاضرات تفاعلية.
#
# ويسعدني بداية...
# Read More
#
#
#
#
#
#
# PSUT
#
# Founded in 1991, Princess Sumaya University for Technology (PSUT) is the only private and non-profit university in Jordan. It is owned by the Royal Scientific Society (RSS), the foremost applied research center in Jordan. Like RSS, PSUT is part of El Hassan Science City located in Amman, Jordan....
# Read More
#
#
#
#
#
#
# PSUT -IEEExtreme Programming Competition
#
# In the face of unprecedented competition, Princess Sumaya University for Technology snatched first place in the world, in addition to other advanced positions, in the annual IEEEXtreme Programming Competition, which is organized by IEEE. The University came out victorious against a participation of...
# Read More
#
#
#
#
#
#
# PSUT-QS
#
# The QS Intelligence Unit has, through rigorous and independent data collection and analysis of performance metrics as set out in the QS Stars™ methodology, rated PRINCESS SUMAYA UNIVERSITY FOR TECHNOLOGY as a Five Stars institution.
# Read More
#
#
#
#
#
#
# PSUT
#
# Founded in 1991, Princess Sumaya University for Technology (PSUT) is the only private and non-profit university in Jordan. It is owned by the Royal Scientific Society (RSS), the foremost applied research center in Jordan. Like RSS, PSUT is part of El Hassan Science City located in Amman, Jordan....
# Read More
#
#
#
#
#
#
# PSUT
#
# Founded in 1991, Princess Sumaya University for Technology (PSUT) is the only private and non-profit university in Jordan. It is owned by the Royal Scientific Society (RSS), the foremost applied research center in Jordan. Like RSS, PSUT is part of El Hassan Science City located in Amman, Jordan....
# Read More
#
#
#
#
#
#
# PSUT
#
# Founded in 1991, Princess Sumaya University for Technology (PSUT) is the only private and non-profit university in Jordan. It is owned by the Royal Scientific Society (RSS), the foremost applied research center in Jordan. Like RSS, PSUT is part of El Hassan Science City located in Amman, Jordan....
# Read More
#
#
#
#
#
#
# PSUT
#
# Founded in 1991, Princess Sumaya University for Technology (PSUT) is the only private and non-profit university in Jordan. It is owned by the Royal Scientific Society (RSS), the foremost applied research center in Jordan. Like RSS, PSUT is part of El Hassan Science City located in Amman, Jordan....
# Read More
#
#
#
#
#
#
# psut
#
# Founded in 1991, Princess Sumaya University for Technology (PSUT) is the only private and non-profit university in Jordan. It is owned by the Royal Scientific Society (RSS), the foremost applied research center in Jordan. Like RSS, PSUT is part of El Hassan Science City located in Amman, Jordan....
# Read More
#
#
#
#
#
#
# PSUT
#
# Founded in 1991, Princess Sumaya University for Technology (PSUT) is the only private and non-profit university in Jordan. It is owned by the Royal Scientific Society (RSS), the foremost applied research center in Jordan. Like RSS, PSUT is part of El Hassan Science City located in Amman, Jordan....
# Read More
#
#
#
#
#
#
# PSUT
#
# Founded in 1991, Princess Sumaya University for Technology (PSUT) is the only private and non-profit university in Jordan. It is owned by the Royal Scientific Society (RSS), the foremost applied research center in Jordan. Like RSS, PSUT is part of El Hassan Science City located in Amman, Jordan....
# Read More
#
#
#
#
#
#
# PSUT
# About Us
# Founded in 1991, Princess Sumaya University for Technology (PSUT) is the only private and non-profit university in Jordan. It is owned by the Royal Scientific Society (RSS), the foremost applied research center in Jordan. Like RSS, PSUT is part of El Hassan Science City located in Amman, Jordan....
# Read More
#
#
#
#
#
#
# PSUT
# About Us
# Founded in 1991, Princess Sumaya University for Technology (PSUT) is the only private and non-profit university in Jordan. It is owned by the Royal Scientific Society (RSS), the foremost applied research center in Jordan. Like RSS, PSUT is part of El Hassan Science City located in Amman, Jordan....
# Read More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Your Admission Platform
#
#           Princess Sumaya University for Technology
#
# All of PSUT's Schools are accredited by American accreditation organizations
#
#
#
# ...
#           Read More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       Employees
#
#
#
#
#
#
#
#
#
#
#
#           Employee Services:
#
# Photo Gallery, Video Gallery ,Email ,E-services , EDF, Online Registration, Elearning
#
#
#
#           Read More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       Students
#
#
#
#
#
#
#
#
#
#
#
#           Students Services:
#
# Online Registration,Study in Jordan ,Study in US, International Students, Success Stories , Elearning ,Email, Student Notebook, Innovations Students , video gallery , YearBook   , Academic Calendar
#
#
#
#
#
#
#
#
#
#
#
#           Read More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       University
#
#
#
#
#
#
#
#
#
#
#
#
#     Your Admission Platform
#
#
#
#
#     Student Portal
#
#
#
#
#     E-Services
#
#
#
#
#     E-learning
#
#
#
#
#     University                                       of Arizona
#
#
#
#
#     STUDY ABROAD
#
#
#
#
#     Your Recruitment                                   Platform
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       ANNOUNCEMENTS
#
#
#
#
#
#
#
#
#
#
#
#           03/01/2022
# بدء استلام طلبات الالتحاق للفصل الدراسي الثاني 2022/2021
#
#
#
#
#           02/12/2021
# اعلان فتح باب التسجيل لبرامج الماجستير للفصل الدراسي الثاني
#
#
#
#
#
#
#
#
#     View All
#
#
#
#
#
#
#
#
#
#
#
#       News
#
#
#
#
#
#
#
#
#
#
#
# 06
# March
#
#           01:03
#           The Queen Rania National Entrepreneurship Competition opens its doors to entrants for its 12th editi...
#
#
#
# 06
# March
#
#           12:03
#           PSUT student Eyad Odeh takes bronze medal in the Asian Fencing Championships
#
#
#
# 02
# March
#
#           12:03
#            PSUT wins the CFA Challenge and goes through to the regional qualifiers in Dubai
#
#
#
#
#
#
#
#     View All
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       Magazine
#
#
#
#
#
#
#
#
#
#
#
#           10 March
#            Journal of JJCIT, University Magazine,Student's Voice Magazine , PSUT Harvest Achievements Issue
#
#
#
#           View
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     King Hussein Schoolof Computing SciencesNewsnews/King Hussein Faculty of Computing SciencesProgramscontent/computer-science-bscDepartmentscontent/computer-graphics-and-animation-0
#
#
#
#     King Abdullah II Schoolof EngineeringNewsnews/King Abdullah II Faculty of EngineeringPrograms/content/electronics-engineering-bsc-aboutDepartmentsnode/659
#
#
#
#     King Talal Schoolof Business TechnologyNewsnews/King Talal Faculty of Business and TechnologyProgramscontent/about-16Departmentscontent/accounting
#
#
#
#     King Abdullah I Schoolof Graduate Studies and Scientific ResearchNewsnews/King Abdullah I Faculty of Graduate Studies and Scientific ResearchProgramscontent/phd-computer-scienceDepartmentscontent/message-dean-0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   UniversityVisitors
# Partners
# Instructions and Regulations
# International Projects
#
# AcademicsGraduate Studies
# School of Computing Sciences
# School of Engineering
# School of Business  Technology
# Admission and Registration Deanship
# Student Affairs
#
# ServicesE-learning
# Employees
# Students
# Academic Calendar
#
# UnitsCenter of Consultancy and Training
# El Hassan Library
# Financial Affairs
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Signup for Newsletter
#
#
#   E-mail *
#
#
# Subscribe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     facebook
# Twitter
# Youtube
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Policy
# Support
